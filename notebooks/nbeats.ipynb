# %%
import pandas as pd
from nbeats_forecast import NBeats
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score


def calculate_loss(yhat, test_y):
    rmse = mean_squared_error(yhat, test_y) ** 0.5
    r2 = r2_score(test_y, yhat, multioutput = "variance_weighted")
    return rmse, r2


data = pd.read_csv('../datasets/weather_energy_hourly.csv')
data = data.avg_energy.values        #univariate time series data of shape nx1 (numpy array)
data = data.reshape(-1,1)
print(data.shape)
# Out:
# (19862, 1)

# %%
model = NBeats(data=data, period_to_forecast=49)
model.fit()
forecast = model.predict()
rmse, r2 = calculate_loss(data[-49:], forecast)
print(rmse, r2)
print('$$$$$$$$$$$$$$$$$$$$$$$$$$$$')
print(forecast)
print(data[-49])
# Out:
# | N-Beats
# | --  Stack Generic (#0) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=7, backcast_length=147, forecast_length=49, share_thetas=False) at @2664110429856
#      | -- GenericBlock(units=128, thetas_dim=7, backcast_length=147, forecast_length=49, share_thetas=False) at @2664110430640
#      | -- GenericBlock(units=128, thetas_dim=7, backcast_length=147, forecast_length=49, share_thetas=False) at @2664110431144
# | --  Stack Generic (#1) (share_weights_in_stack=False)
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=147, forecast_length=49, share_thetas=False) at @2664110431648
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=147, forecast_length=49, share_thetas=False) at @2664110431424
#      | -- GenericBlock(units=128, thetas_dim=8, backcast_length=147, forecast_length=49, share_thetas=False) at @2664112918600
# grad_step = 000030, tr_loss = 0.226451, te_loss = 0.598644
# grad_step = 000060, tr_loss = 0.042783, te_loss = 0.598644
# grad_step = 000090, tr_loss = 0.019363, te_loss = 0.598644
# grad_step = 000120, tr_loss = 0.018065, te_loss = 0.021461
# grad_step = 000150, tr_loss = 0.017232, te_loss = 0.021461
# grad_step = 000180, tr_loss = 0.016207, te_loss = 0.021461
# grad_step = 000210, tr_loss = 0.015250, te_loss = 0.018080
# grad_step = 000240, tr_loss = 0.014434, te_loss = 0.018080
# grad_step = 000270, tr_loss = 0.013381, te_loss = 0.018080
# grad_step = 000300, tr_loss = 0.012488, te_loss = 0.018080
# grad_step = 000330, tr_loss = 0.011698, te_loss = 0.014244
# grad_step = 000360, tr_loss = 0.010730, te_loss = 0.014244
# grad_step = 000390, tr_loss = 0.010025, te_loss = 0.014244
# grad_step = 000420, tr_loss = 0.009379, te_loss = 0.011063
# grad_step = 000450, tr_loss = 0.009067, te_loss = 0.011063
# grad_step = 000480, tr_loss = 0.008340, te_loss = 0.011063
# grad_step = 000510, tr_loss = 0.007922, te_loss = 0.008821
# grad_step = 000540, tr_loss = 0.007548, te_loss = 0.008821
# grad_step = 000570, tr_loss = 0.007313, te_loss = 0.008821
# grad_step = 000600, tr_loss = 0.006939, te_loss = 0.008821
# grad_step = 000630, tr_loss = 0.006672, te_loss = 0.007532
# grad_step = 000660, tr_loss = 0.006446, te_loss = 0.007532
# grad_step = 000690, tr_loss = 0.006226, te_loss = 0.007532
# grad_step = 000720, tr_loss = 0.006177, te_loss = 0.006688
# grad_step = 000750, tr_loss = 0.005841, te_loss = 0.006688
# grad_step = 000780, tr_loss = 0.005841, te_loss = 0.006688
# grad_step = 000810, tr_loss = 0.005510, te_loss = 0.006027
# grad_step = 000840, tr_loss = 0.005388, te_loss = 0.006027
# grad_step = 000870, tr_loss = 0.005204, te_loss = 0.006027
# grad_step = 000900, tr_loss = 0.005271, te_loss = 0.006027
# grad_step = 000930, tr_loss = 0.004944, te_loss = 0.005687
# grad_step = 000960, tr_loss = 0.004891, te_loss = 0.005687
# grad_step = 000990, tr_loss = 0.004727, te_loss = 0.005687
# grad_step = 001020, tr_loss = 0.004702, te_loss = 0.005058
# grad_step = 001050, tr_loss = 0.004490, te_loss = 0.005058
# grad_step = 001080, tr_loss = 0.004370, te_loss = 0.005058
# grad_step = 001110, tr_loss = 0.004271, te_loss = 0.004733
# grad_step = 001140, tr_loss = 0.004205, te_loss = 0.004733
# grad_step = 001170, tr_loss = 0.004100, te_loss = 0.004733
# grad_step = 001200, tr_loss = 0.004123, te_loss = 0.004733
# grad_step = 001230, tr_loss = 0.003891, te_loss = 0.004588
# grad_step = 001260, tr_loss = 0.003922, te_loss = 0.004588
# grad_step = 001290, tr_loss = 0.003775, te_loss = 0.004588
# grad_step = 001320, tr_loss = 0.003738, te_loss = 0.004054
# grad_step = 001350, tr_loss = 0.003617, te_loss = 0.004054
# grad_step = 001380, tr_loss = 0.003524, te_loss = 0.004054
# grad_step = 001410, tr_loss = 0.003425, te_loss = 0.003705
# grad_step = 001440, tr_loss = 0.003370, te_loss = 0.003705
# grad_step = 001470, tr_loss = 0.003581, te_loss = 0.003705
# grad_step = 001500, tr_loss = 0.003214, te_loss = 0.003705
# grad_step = 001530, tr_loss = 0.003168, te_loss = 0.003509
# grad_step = 001560, tr_loss = 0.003194, te_loss = 0.003509
# grad_step = 001590, tr_loss = 0.003053, te_loss = 0.003509
# grad_step = 001620, tr_loss = 0.002984, te_loss = 0.003318
# grad_step = 001650, tr_loss = 0.002909, te_loss = 0.003318
# grad_step = 001680, tr_loss = 0.002905, te_loss = 0.003318
# grad_step = 001710, tr_loss = 0.002809, te_loss = 0.002981
# grad_step = 001740, tr_loss = 0.002764, te_loss = 0.002981
# grad_step = 001770, tr_loss = 0.002860, te_loss = 0.002981
# grad_step = 001800, tr_loss = 0.002681, te_loss = 0.002981
# grad_step = 001830, tr_loss = 0.002622, te_loss = 0.002834
# grad_step = 001860, tr_loss = 0.002698, te_loss = 0.002834
# grad_step = 001890, tr_loss = 0.002540, te_loss = 0.002834
# grad_step = 001920, tr_loss = 0.002533, te_loss = 0.002624
# grad_step = 001950, tr_loss = 0.002455, te_loss = 0.002624
# grad_step = 001980, tr_loss = 0.002606, te_loss = 0.002624
# grad_step = 002010, tr_loss = 0.002386, te_loss = 0.002475
# grad_step = 002040, tr_loss = 0.002377, te_loss = 0.002475
# grad_step = 002070, tr_loss = 0.002311, te_loss = 0.002475
# grad_step = 002100, tr_loss = 0.002320, te_loss = 0.002475
# grad_step = 002130, tr_loss = 0.002256, te_loss = 0.002371
# grad_step = 002160, tr_loss = 0.002242, te_loss = 0.002371
# grad_step = 002190, tr_loss = 0.002195, te_loss = 0.002371
# grad_step = 002220, tr_loss = 0.002172, te_loss = 0.002250
# grad_step = 002250, tr_loss = 0.002118, te_loss = 0.002250
# grad_step = 002280, tr_loss = 0.002268, te_loss = 0.002250
# grad_step = 002310, tr_loss = 0.002067, te_loss = 0.002110
# grad_step = 002340, tr_loss = 0.002084, te_loss = 0.002110
# grad_step = 002370, tr_loss = 0.002080, te_loss = 0.002110
# grad_step = 002400, tr_loss = 0.002004, te_loss = 0.002110
# grad_step = 002430, tr_loss = 0.002033, te_loss = 0.002004
# grad_step = 002460, tr_loss = 0.001975, te_loss = 0.002004
# grad_step = 002490, tr_loss = 0.001960, te_loss = 0.002004
# 0.07466041220106052 0.686649916087059
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$
# [[0.27857098]
#  [0.2377189 ]
#  [0.24186333]
#  [0.21060626]
#  [0.2626081 ]
#  [0.29277176]
#  [0.36770156]
#  [0.44019738]
#  [0.46293488]
#  [0.42521766]
#  [0.4484958 ]
#  [0.4249236 ]
#  [0.42005944]
#  [0.45743102]
#  [0.48920247]
#  [0.5002312 ]
#  [0.54667413]
#  [0.592672  ]
#  [0.657588  ]
#  [0.6358015 ]
#  [0.63646305]
#  [0.563784  ]
#  [0.4696373 ]
#  [0.38304815]
#  [0.2772968 ]
#  [0.22139844]
#  [0.21207331]
#  [0.21302386]
#  [0.25453913]
#  [0.3420702 ]
#  [0.3934926 ]
#  [0.374032  ]
#  [0.4600603 ]
#  [0.39993018]
#  [0.44821912]
#  [0.42978403]
#  [0.42932215]
#  [0.4214502 ]
#  [0.44830182]
#  [0.50423163]
#  [0.58263165]
#  [0.6209    ]
#  [0.65831643]
#  [0.66369367]
#  [0.63045573]
#  [0.5710068 ]
#  [0.47477618]
#  [0.3497758 ]
#  [0.286102  ]]
# [0.38331372]

# %%
print(data[-49:])
# Out:
# [[0.38331372]
#  [0.30474151]
#  [0.25721706]
#  [0.235     ]
#  [0.227689  ]
#  [0.24219171]
#  [0.30253852]
#  [0.41790042]
#  [0.4641032 ]
#  [0.43030376]
#  [0.4060597 ]
#  [0.38319156]
#  [0.38733602]
#  [0.39121988]
#  [0.37950234]
#  [0.37855321]
#  [0.40396922]
#  [0.48557292]
#  [0.64564688]
#  [0.71815122]
#  [0.70052745]
#  [0.6436132 ]
#  [0.56992956]
#  [0.45540491]
#  [0.38751763]
#  [0.30110861]
#  [0.25323954]
#  [0.23517834]
#  [0.22596441]
#  [0.24046008]
#  [0.3037032 ]
#  [0.41624536]
#  [0.47878323]
#  [0.43485904]
#  [0.41735069]
#  [0.39392942]
#  [0.39153891]
#  [0.39691816]
#  [0.37956807]
#  [0.39299075]
#  [0.42626222]
#  [0.50451514]
#  [0.65509471]
#  [0.71888373]
#  [0.69115815]
#  [0.65402595]
#  [0.5843233 ]
#  [0.46686585]
#  [0.20880571]]
